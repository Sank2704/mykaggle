# %% [markdown]
# # Exploring the Cars DataSet using the Pandas Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('cars.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
# Unnamed: 0    32 non-null object
# mpg           32 non-null float64
# cyl           32 non-null int64
# disp          32 non-null float64
# hp            32 non-null int64
# drat          32 non-null float64
# wt            32 non-null float64
# qsec          32 non-null float64
# vs            32 non-null int64
# am            32 non-null int64
# gear          32 non-null int64
# carb          32 non-null int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
df.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.rename(columns={'Unnamed: 0':'Car Name'},inplace=True)

# %%
df.head()
# Out:
#             Car Name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.isnull().sum()
# Out:
# Car Name    0
# mpg         0
# cyl         0
# disp        0
# hp          0
# drat        0
# wt          0
# qsec        0
# vs          0
# am          0
# gear        0
# carb        0
# dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Car Name'])
# Out:
# pandas.core.series.Series

# %%
len(df)
# ?len

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
df1 = pd.read_csv('cars1.csv')
df2 = pd.read_csv('cars2.csv')

# %%
df1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df2.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  33.0          4            91         53    1795          17.4     76
# 1  20.0          6           225        100    3651          17.7     76
# 2  18.0          6           250         78    3574          21.0     76
# 3  18.5          6           250        110    3645          16.2     76
# 4  17.5          6           258         95    3193          17.8     76
#
#    origin                 car
# 0       3         honda civic
# 1       1      dodge aspen se
# 2       1   ford granada ghia
# 3       1  pontiac ventura sj
# 4       1       amc pacer d/l

# %%
frames = [df1,df2]
df_final = pd.concat(frames)
df_final.reset_index(inplace=True)

# %%
df_final.head()
# Out:
#    index   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0      0  18.0          8           307        130    3504          12.0
# 1      1  15.0          8           350        165    3693          11.5
# 2      2  18.0          8           318        150    3436          11.0
# 3      3  16.0          8           304        150    3433          12.0
# 4      4  17.0          8           302        140    3449          10.5
#
#    model  origin                        car
# 0     70       1  chevrolet chevelle malibu
# 1     70       1          buick skylark 320
# 2     70       1         plymouth satellite
# 3     70       1              amc rebel sst
# 4     70       1                ford torino

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
# index           398 non-null int64
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null int64
# horsepower      398 non-null object
# weight          398 non-null int64
# acceleration    398 non-null float64
# model           398 non-null int64
# origin          398 non-null int64
# car             398 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 31.2+ KB

# %%
print(df1.shape)
print(df2.shape)
print(df_final.shape)
# Out:
# (198, 9)
# (200, 9)
# (398, 10)

# %%
new_row = np.random.randint(15000,73000,size=398)
new_row
# Out:
# array([57914, 29454, 44568, 38543, 51603, 25313, 59881, 43783, 68401,
#        68120, 18901, 19371, 71607, 39443, 33364, 66017, 46617, 50724,
#        36093, 18420, 60699, 71158, 25339, 36194, 29532, 51729, 27036,
#        31821, 65203, 44041, 54493, 53996, 46854, 72380, 62264, 58990,
#        42881, 32511, 28371, 43766, 45503, 21080, 50924, 62176, 63274,
#        20750, 31603, 52909, 56967, 70380, 43772, 30801, 23139, 69401,
#        58190, 38409, 59129, 42307, 61000, 69722, 50566, 19434, 68127,
#        22740, 64220, 53999, 47893, 32113, 25816, 63577, 70423, 38862,
#        26434, 32846, 66878, 38013, 40337, 33101, 70263, 26107, 53537,
#        49175, 52957, 61908, 23859, 58759, 20861, 27851, 66082, 34449,
#        48565, 54560, 51863, 53382, 30841, 47687, 43641, 54978, 67965,
#        42266, 42650, 39755, 26628, 21907, 16116, 30429, 29936, 15784,
#        18439, 41365, 39465, 64786, 30927, 59173, 67660, 65079, 18074,
# ...

# %%
df_final['owners'] = new_row
df_final['ownhkkjers'] = new_row

# %%
df_final.head()
# Out:
#    index   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0      0  18.0          8           307        130    3504          12.0
# 1      1  15.0          8           350        165    3693          11.5
# 2      2  18.0          8           318        150    3436          11.0
# 3      3  16.0          8           304        150    3433          12.0
# 4      4  17.0          8           302        140    3449          10.5
#
#    model  origin                        car  owners  ownhkkjers
# 0     70       1  chevrolet chevelle malibu   57914       57914
# 1     70       1          buick skylark 320   29454       29454
# 2     70       1         plymouth satellite   44568       44568
# 3     70       1              amc rebel sst   38543       38543
# 4     70       1                ford torino   51603       51603

# %%
df_final = df_final.drop(['ownhkkjers'],axis=1)

# %%
df_final.head()
# Out:
#    index   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0      0  18.0          8           307        130    3504          12.0
# 1      1  15.0          8           350        165    3693          11.5
# 2      2  18.0          8           318        150    3436          11.0
# 3      3  16.0          8           304        150    3433          12.0
# 4      4  17.0          8           302        140    3449          10.5
#
#    model  origin                        car  owners
# 0     70       1  chevrolet chevelle malibu   57914
# 1     70       1          buick skylark 320   29454
# 2     70       1         plymouth satellite   44568
# 3     70       1              amc rebel sst   38543
# 4     70       1                ford torino   51603

# %%
graph1 = sns.lmplot(x='cylinders',y='mpg',hue='model',data=df_final)

# %% [markdown]
# # Car Name with max mpg

# %%
df_final[[df_final['mpg'].max()]]['car']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-144-341b24b00191> in <module>()
# ----> 1 df_final[[df_final['mpg'].max()]]['car']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# ...

# %%
print(df_final['mpg'].max())
print(df_final['mpg'].min())
# Out:
# 46.6
# 9.0

# %%
df_final.loc[df_final['mpg'].argmax()]['car']
# Out:
# 'mazda glc'

# %%
df_final.loc[df_final['mpg'].idxmax()]
# Out:
# index                 124
# mpg                  46.6
# cylinders               4
# displacement           86
# horsepower             65
# weight               2110
# acceleration         17.9
# model                  80
# origin                  3
# car             mazda glc
# owners              45446
# Name: 322, dtype: object

# %%
df_final['mpg'].max()
# Out:
# 46.600000000000001

# %%
df_final.loc[df_final['mpg'].idxmax()  & df_final['cylinders'].idxmax()]
# Out:
# index                                   0
# mpg                                    18
# cylinders                               8
# displacement                          307
# horsepower                            130
# weight                               3504
# acceleration                           12
# model                                  70
# origin                                  1
# car             chevrolet chevelle malibu
# owners                              57914
# Name: 0, dtype: object

# %%
##Car Name with Mx Clinders and Max Mileage

# %%
df_final.loc[df_final['mpg'].idxmax()  & df_final['cylinders'].idxmax()]['car']
# Out:
# 'chevrolet chevelle malibu'

# %%
df_final.sort_values('car')
# Out:
#      index   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 96      96  13.0          8           360        175    3821          11.0
# 9        9  15.0          8           390        190    3850           8.5
# 66      66  17.0          8           304        150    3672          11.5
# 315    117  24.3          4           151         90    3003          20.1
# 257     59  19.4          6           232         90    3210          17.2
# 261     63  18.1          6           258        120    3410          15.1
# 374    176  23.0          4           151          ?    3035          20.5
# 283     85  20.2          6           232         90    3265          18.2
# 107    107  18.0          6           232        100    2789          15.0
# 33      33  19.0          6           232        100    2634          13.0
# 169    169  20.0          6           232        100    2914          16.0
# ...

# %%
df_final.isnull().sum()
# Out:
# index           0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model           0
# origin          0
# car             0
# owners          0
# dtype: int64

# %%
##Unique values from Cylinder Column

# %%
np.unique(df_final['cylinders'])
# Out:
# array([3, 4, 5, 6, 8], dtype=int64)

# %%
df_final['cylinders'].mode()
# Out:
# 0    4
# dtype: int64

# %%
df_final.cylinders.describe()
# Out:
# count    398.000000
# mean       5.454774
# std        1.701004
# min        3.000000
# 25%        4.000000
# 50%        4.000000
# 75%        8.000000
# max        8.000000
# Name: cylinders, dtype: float64

# %%
df_final.mpg.mean()
# Out:
# 23.514572864321615

# %%
df_final.mpg.value_counts().tail()
# Out:
# 34.2    1
# 38.1    1
# 37.2    1
# 32.1    1
# 32.7    1
# Name: mpg, dtype: int64
